# %%
# !git clone https://github.com/architkaila/recommenders_aipi590.git

# %%
# !pip install trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting trfl
#   Downloading trfl-1.2.0-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 15.0 MB/s
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from trfl) (0.1.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from trfl) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from trfl) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from trfl) (1.15.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from trfl) (1.14.1)
# Installing collected packages: trfl
# Successfully installed trfl-1.2.0

# %%
# !wget https://aipi590.s3.amazonaws.com/transactions_train.csv -P "/content/recommenders_aipi590/DRL_Recommenders/Dataset_2_HM/HM_data/"

# %%
# !python "/content/recommenders_aipi590/DRL_Recommenders/Dataset_2_HM/src/gen_replay_buffer.py" --size=20000 --format=paper --data="/content/recommenders_aipi590/DRL_Recommenders/Dataset_2_HM/HM_data/"

# %%
# !python "/content/recommenders_aipi590/DRL_Recommenders/Dataset_2_HM/src/SNQN_v2.py" --model=SASRec --data="/content/recommenders_aipi590/DRL_Recommenders/Dataset_2_HM/HM_data/" --epoch=20
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SNQN_v2.py:188: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   self.seq = tf.compat.v1.layers.dropout(self.seq,
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:142: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   Q = tf.compat.v1.layers.dense(queries, num_units, activation=None) # (N, T_q, C)
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:143: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   K = tf.compat.v1.layers.dense(keys, num_units, activation=None) # (N, T_k, C)
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:144: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   V = tf.compat.v1.layers.dense(keys, num_units, activation=None) # (N, T_k, C)
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:184: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   outputs = tf.compat.v1.layers.dropout(outputs, rate=dropout_rate, training=tf.convert_to_tensor(value=is_training))
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:223: UserWarning: `tf.layers.conv1d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv1D` instead.
#   outputs = tf.compat.v1.layers.conv1d(**params)
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:224: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   outputs = tf.compat.v1.layers.dropout(outputs, rate=dropout_rate, training=tf.convert_to_tensor(value=is_training))
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:228: UserWarning: `tf.layers.conv1d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv1D` instead.
#   outputs = tf.compat.v1.layers.conv1d(**params)
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SASRecModules.py:229: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   outputs = tf.compat.v1.layers.dropout(outputs, rate=dropout_rate, training=tf.convert_to_tensor(value=is_training))
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SNQN_v2.py:216: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# /content/drive/MyDrive/Kaggle_HM-main/src/models/SNQN_v2.py:219: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# 2022-12-11 07:54:01.054761: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
#
# ********************* Training Started *********************
#
# Starting Epoch: 1
# Number of batches: 580
# Epoch 1 training completed.
# The loss after epoch 1 is: 13.763758659362793
#
# Starting Epoch: 2
# Number of batches: 580
# Epoch 2 training completed.
# The loss after epoch 2 is: 12.579383850097656
#
# Starting Epoch: 3
# Number of batches: 580
# Epoch 3 training completed.
# The loss after epoch 3 is: 11.283208847045898
#
# Starting Epoch: 4
# Number of batches: 580
# Epoch 4 training completed.
# The loss after epoch 4 is: 10.852283477783203
#
# Starting Epoch: 5
# Number of batches: 580
# Epoch 5 training completed.
# The loss after epoch 5 is: 10.260936737060547
#
# Starting Epoch: 6
# Number of batches: 580
# Epoch 6 training completed.
# The loss after epoch 6 is: 9.289750099182129
#
# Starting Epoch: 7
# Number of batches: 580
# Epoch 7 training completed.
# The loss after epoch 7 is: 9.093804359436035
#
# Starting Epoch: 8
# Number of batches: 580
# Epoch 8 training completed.
# The loss after epoch 8 is: 8.138814926147461
#
# Starting Epoch: 9
# Number of batches: 580
# Epoch 9 training completed.
# The loss after epoch 9 is: 7.797699451446533
#
# Starting Epoch: 10
# Number of batches: 580
# Epoch 10 training completed.
# The loss after epoch 10 is: 8.012262344360352
#
# Starting Epoch: 11
# Number of batches: 580
# Epoch 11 training completed.
# The loss after epoch 11 is: 7.347847938537598
#
# Starting Epoch: 12
# Number of batches: 580
# Epoch 12 training completed.
# The loss after epoch 12 is: 6.695550441741943
#
# Starting Epoch: 13
# Number of batches: 580
# Epoch 13 training completed.
# The loss after epoch 13 is: 6.5004963874816895
#
# Starting Epoch: 14
# Number of batches: 580
# Epoch 14 training completed.
# The loss after epoch 14 is: 6.770813465118408
#
# Starting Epoch: 15
# Number of batches: 580
# Epoch 15 training completed.
# The loss after epoch 15 is: 6.603675842285156
#
# Starting Epoch: 16
# Number of batches: 580
# Epoch 16 training completed.
# The loss after epoch 16 is: 6.043393135070801
#
# Starting Epoch: 17
# Number of batches: 580
# Epoch 17 training completed.
# The loss after epoch 17 is: 6.552749156951904
#
# Starting Epoch: 18
# Number of batches: 580
# Epoch 18 training completed.
# The loss after epoch 18 is: 5.761403560638428
#
# Starting Epoch: 19
# Number of batches: 580
# Epoch 19 training completed.
# The loss after epoch 19 is: 5.929544448852539
#
# Starting Epoch: 20
# Number of batches: 580
# Epoch 20 training completed.
# The loss after epoch 20 is: 5.449290752410889
#
# Start evaluation with batch size 30
# tcmalloc: large alloc 1851318272 bytes == 0x87e0e000 @  0x7f59619581e7 0x7f592c1c014e 0x7f592c218745 0x7f592c218878 0x7f592c25e597 0x7f592c2627dc 0x7f592c2b1a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f592c202944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1614995456 bytes == 0xf639c000 @  0x7f59619581e7 0x7f592c1c014e 0x7f592c218745 0x7f592c218878 0x7f592c25e597 0x7f592c2627dc 0x7f592c2b1a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f592c202944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1684275200 bytes == 0x87e0e000 @  0x7f59619581e7 0x7f592c1c014e 0x7f592c218745 0x7f592c218878 0x7f592c25e597 0x7f592c2627dc 0x7f592c2b1a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f592c202944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1691205632 bytes == 0xec44e000 @  0x7f59619581e7 0x7f592c1c014e 0x7f592c218745 0x7f592c218878 0x7f592c25e597 0x7f592c2627dc 0x7f592c2b1a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f592c202944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 3048.000000
# purchase hr and ndcg @5 : 0.024380, 0.015368
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 4542.000000
# purchase hr and ndcg @10 : 0.036330, 0.019200
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 5703.000000
# purchase hr and ndcg @15 : 0.045617, 0.021661
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 6486.000000
# purchase hr and ndcg @20 : 0.051880, 0.023141
# #############################################################
